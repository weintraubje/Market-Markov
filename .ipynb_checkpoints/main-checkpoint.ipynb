# %%
import pandas as pd
import numpy as np

import yfinance as yf
import datetime as dt

from matplotlib import pyplot as plt

from importlib import reload

import download_data as dd
reload(dd)
# Out:
# <module 'download_data' from 'C:\\Users\\Jeffrey\\Desktop\\Homework\\Market-Markov\\download_data.py'>

# %% [markdown]
# # Set Controls
#
# #### Time of Program

# %%
start = dt.datetime(2010,1,1)
end = dt.datetime(2020,12,31)

# %% [markdown]
# #### Basket of Stocks

# %%
symbols = ['SPYG', 'SPYD', 'SPY', 'MSFT', 'AMZN', 'TSLA', 'AAPL', 'GOOGL', 
           'FB', 'BABA', 'TSM', 'V', 'JPM', 'JNJ', 'WMT', 'MA', 'NVDA',
           'UNH', 'BAC', 'HD', 'DIS', 'PG', 'PYPL', 'CMCSA', 'XOM', 'VZ',
           'KO', 'NFLX', 'T', 'ORCL', 'CSCO', 'CRM', 'PFE', 'ABT', 'TMT',
           'NKE', 'CVX', 'PEP', 'ABBV', 'ACN', 'NVS', 'WFC', 'AVGO', 'MRK',
           'DHR', 'TMO', 'MDT', 'UPS', 'MCD', 'LLY', 'TXN', 'SAP', 'TMUS',
           'COST', 'QCOM', 'HON', 'UL', 'C', 'SHOP', 'NEE', 'LIN', 'UNP']
#symbols = ['SPYG', 'SPYD', 'SPY']

# %%
def download_stock_data(symbol, start, end):
    """Downloads historical stock pricing data for an individual symbol"""

    df = pd.DataFrame()  

    # Print the symbol being downloaded
    print('DOWNLOADING ' + symbol, sep=',', end=' ... ', flush=True)  

    try:
        # Download pricing data
        stock = []
        stock = yf.download(symbol, start=start, end=end, progress=False)

        # Append individual prices
        if len(stock) == 0:
            None
        else:
            stock['Name'] = symbol
            df = df.append(stock,sort=False)
            df = df[['Close', 'Name']]
            print('SUCCESS!')
            
    except Exception:
        print('ERROR IN DOWNLOADING DATA')
               
    
    return df



def day_change_transitions(df, num_days):
    """Calculates a measure of change from good/middle/bad days to good/middle/bad."""
    
    # Controls
    min_change = 0.01
    
    # How has the stock performed in the last X days?
    df[str(num_days)+'D Change'] = df['Close'] - df.loc[:,'Close'].shift(num_days)
    df[str(num_days)+'D Change Switch'] = np.where(df[str(num_days)+'D Change'] > 0, True, False)

    # Is the change significant?
    df['Change Percent Value'] = np.absolute(df[str(num_days)+'D Change'] / df['Close'])
    df['Change Percent Value Switch'] = np.where(df['Change Percent Value'] > min_change, True, False)

    # Combine everything
    conditions = [
        (df[str(num_days)+'D Change Switch'] == True) & (df['Change Percent Value Switch'] == True),
        (df[str(num_days)+'D Change Switch'] == False) & (df['Change Percent Value Switch'] == True),
        (df['Change Percent Value Switch'] == False)]
    
    # Assign categories
    choices = [0, 1, 2]
    df['Output'] = np.select(conditions, choices, default = 2)
    
    # Isolate transitions
    transitions = list(df['Output'])[num_days:]
    
    return transitions



def generate_transition_matrix(l, split_size):
    """Generates a transition matrix from a list of data"""
    
    # Identify all unique elements and create an empty transition matrix
    elements = list(set(l))
    print(elements)
    elements_len = len(elements)
    transition_matrix = [[0] * elements_len for x in range(elements_len)]

    # Create a zipped pair of each state and its next, and then a transition matrix
    for (i,j) in zip(l,l[split_size:]):
        transition_matrix[i][j] += 1
    for i in transition_matrix:
        if sum(i) > 0:
            i[:] = [x/sum(i) for x in i]
    
    return transition_matrix



def generate_combine_transition_matrices(symbols, start, end, min_days = 1, max_days = 1):
    """Runs each part of the progrm for each symbol and combines the transition matrices"""
    
    list_tm = []
    
    # Generate transition matrix for each symbol
    for i in symbols:
        df = download_stock_data(i, start, end)
        list_inner_tm = []
        for j in list(range(min_days, max_days + 1)):
            transitions = day_change_transitions(df, j)
            transition_matrix = generate_transition_matrix(transitions, j)
            list_inner_tm.append(transition_matrix)
        list_tm.append(list_inner_tm)
    
    # Average transition matrix for each symbol, this still satisfies Kolmogorov axioms
    avg_list, first, c_s = [], True, 0
    for i in list_tm:
        c = 0
        print(i.index)
        for j in i:
            try:
                if first == True:
                    avg_list.append(np.array(j))
                else:
                    avg_list[c] = avg_list[c] + np.array(j)
                    c = c + 1
            except:
                print('ERROR OCCURS AT ENTRY '+str(c)+' FOR EQUITY '+symbols[c_s])
                c = c + 1
                continue
        first = False
        c_s = c_s + 1
    for k in range(0, len(avg_list)):
        avg_list[k] = avg_list[k] / len(symbols)

    return avg_list
    


def stationary_values(transition_matrix, mmult_number = 50):
    """From a transition matrix, generate stationary values"""
            
    # Create a 1st state array
    state = np.array([[0.0] * len(transition_matrix)])
    state[0][0] = 1.0

    # Create a state tracker
    stateHist = state
    dfStateHist = pd.DataFrame(state)
    distr_hist = [[0,0]]
    
    # Calculate stationary values
    for x in range(mmult_number):
        state = np.dot(state, transition_matrix)
        stateHist = np.append(stateHist,state,axis=0)
        dfDistrHist = pd.DataFrame(stateHist)
    svals = dfDistrHist[-1:].iloc[0]
        
    return svals


def plot_summaries(tms):
    """Plot it basic"""
    l_stationary = []
    for _ in tms:
        l_stationary.append(list(stationary_values([list(x) for x in _])))

    for j in range(0, 3):
        x = [x[j] for x in l_stationary]
        plt.plot(x)
    plt.legend(['Good', 'Bad', 'No Change'])
    plt.title('Stationary Odds for Lengths of Time of Measurements')
    plt.ylabel('Chance of Occurance')
    plt.xlabel('Days')
    plt.show()
    
    for i in range(0, 2):
        for j in range(0, 2):
            x = np.array([x[i][j] for x in tms])
            plt.plot(x)
    plt.legend(['Good >>> Good', 'Good >>> Bad', 'Bad >>> Good', 'Bad >>> Bad'])
    plt.title('Transition Odds for Lengths of Time of Measurements')
    plt.ylabel('Chance of Occurance')
    plt.xlabel('Days')
    plt.show()
    
    for i in range(0, 2):
        for j in range(0, 2):
            x = np.array([x[i][j] for x in tms])
            x = x - [x[j] for x in l_stationary]
            plt.plot(x)
    # Plot single line
    plt.plot([0 for x in x])
    plt.legend(['Good >>> Good', 'Good >>> Bad', 'Bad >>> Good', 'Bad >>> Bad', 'Baseline'])
    plt.title('Adjusted for Stationary Odds')
    plt.ylabel('Chance of Occurance')
    plt.xlabel('Days')
    plt.show()
    
    for i in range(0, 3):
        x = np.array([1/(1-x[i][i]) if x[i][i] else None for x in tms])        
        plt.plot(x)
    plt.legend(['Good', 'Bad', 'No Change'])
    plt.title('Mean Time in State')
    plt.ylabel('Mean Time in State')
    plt.xlabel('Days')
    plt.show()
    
    
    return None

# %%
tms = generate_combine_transition_matrices(symbols, start=start, end=end, min_days = 1, max_days = 100)
plot_summaries(tms)
# Out:
# DOWNLOADING SPYG ... SUCCESS!
# DOWNLOADING SPYD ... SUCCESS!
# DOWNLOADING SPY ... SUCCESS!
# DOWNLOADING MSFT ... SUCCESS!
# DOWNLOADING AMZN ... SUCCESS!
# DOWNLOADING TSLA ... SUCCESS!
# DOWNLOADING AAPL ... SUCCESS!
# DOWNLOADING GOOGL ... SUCCESS!
# DOWNLOADING FB ... SUCCESS!
# DOWNLOADING BABA ... SUCCESS!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-ca4c73239b88> in <module>
# ----> 1 tms = generate_combine_transition_matrices(symbols, start=start, end=end, min_days = 1, max_days = 100)
#       2 plot_summaries(tms)
#
# <ipython-input-25-cc7f4fbaa929> in generate_combine_transition_matrices(symbols, start, end, min_days, max_days)
#      96         for j in list(range(min_days, max_days + 1)):
#      97             transitions = day_change_transitions(df, j)
# ---> 98             transition_matrix = generate_transition_matrix(transitions, j)
#      99             list_inner_tm.append(transition_matrix)
#     100         list_tm.append(list_inner_tm)
#
# <ipython-input-25-cc7f4fbaa929> in generate_transition_matrix(l, split_size)
#      76     # Create a zipped pair of each state and its next, and then a transition matrix
#      77     for (i,j) in zip(l,l[split_size:]):
# ---> 78         transition_matrix[i][j] += 1
#      79     for i in transition_matrix:
#      80         if sum(i) > 0:
#
# IndexError: list index out of range

# %%
def download_stock_data(symbol, start, end):
    """Downloads historical stock pricing data for an individual symbol"""

    df = pd.DataFrame()  

    # Print the symbol being downloaded
    print('DOWNLOADING ' + symbol, sep=',', end=' ... ', flush=True)  

    try:
        # Download pricing data
        stock = []
        stock = yf.download(symbol, start=start, end=end, progress=False)

        # Append individual prices
        if len(stock) == 0:
            None
        else:
            stock['Name'] = symbol
            df = df.append(stock,sort=False)
            df = df[['Close', 'Name']]
            print('SUCCESS!')
            
    except Exception:
        print('ERROR IN DOWNLOADING DATA')
               
    
    return df



def day_change_transitions(df, num_days):
    """Calculates a measure of change from good/middle/bad days to good/middle/bad."""
    
    # Controls
    min_change = 0.001
    
    # How has the stock performed in the last X days?
    df[str(num_days)+'D Change'] = df['Close'] - df.loc[:,'Close'].shift(num_days)
    df[str(num_days)+'D Change Switch'] = np.where(df[str(num_days)+'D Change'] > 0, True, False)
    
    # How did it perform in the last 3 days
    df['R1'] = df['Close'] - df.loc[:,'Close'].shift(1)
    df['R2'] = df.loc[:,'Close'].shift(1) - df.loc[:,'Close'].shift(2)
    df['R3'] = df.loc[:,'Close'].shift(2) - df.loc[:,'Close'].shift(3)
    df['R4'] = df.loc[:,'Close'].shift(3) - df.loc[:,'Close'].shift(4)
    df['R5'] = df.loc[:,'Close'].shift(4) - df.loc[:,'Close'].shift(5)
    df['Rally'] = np.where((df['R1'] > 0) & (df['R2'] > 0) & (df['R3'] > 0) & (df['R4'] > 0) & (df['R5'] > 0), True, False)

    # Is the change significant?
    df['Change Percent Value'] = np.absolute(df[str(num_days)+'D Change'] / df['Close'])
    df['Change Percent Value Switch'] = np.where(df['Change Percent Value'] > min_change, True, False)

    # Combine everything
    conditions = [
        (df[str(num_days)+'D Change Switch'] == True) & (df['Change Percent Value Switch'] == True) & (df['Rally'] == False),
        (df[str(num_days)+'D Change Switch'] == False) & (df['Change Percent Value Switch'] == True),
        (df['Change Percent Value Switch'] == False), (df['Rally'] == True)]
    
    # Assign categories
    choices = [0, 1, 2, 3]
    df['Output'] = np.select(conditions, choices, default = 2)
    
    # Isolate transitions
    transitions = list(df['Output'])[num_days:]
    
    return transitions



def generate_transition_matrix(l, split_size):
    """Generates a transition matrix from a list of data"""
    
    # Identify all unique elements and create an empty transition matrix
    elements = list(set(l))
    elements_len = len(elements)
    transition_matrix = [[0] * elements_len for x in range(elements_len)]

    # Create a zipped pair of each state and its next, and then a transition matrix
    for (i,j) in zip(l,l[split_size:]):
        transition_matrix[i][j] += 1
    for i in transition_matrix:
        if sum(i) > 0:
            i[:] = [x/sum(i) for x in i]
    
    return transition_matrix



def generate_combine_transition_matrices(symbols, start, end, min_days = 1, max_days = 1):
    """Runs each part of the progrm for each symbol and combines the transition matrices"""
    
    list_tm = []
    
    # Generate transition matrix for each symbol
    for i in symbols:
        df = download_stock_data(i, start, end)
        list_inner_tm = []
        for j in list(range(min_days, max_days + 1)):
            transitions = day_change_transitions(df, j)
            transition_matrix = generate_transition_matrix(transitions, j)
            list_inner_tm.append(transition_matrix)
        list_tm.append(list_inner_tm)
    
    # Average transition matrix for each symbol, this still satisfies Kolmogorov axioms
    avg_list, first, c_s = [], True, 0
    for i in list_tm:
        c = 0
        print(i.index)
        for j in i:
            try:
                if first == True:
                    avg_list.append(np.array(j))
                else:
                    avg_list[c] = avg_list[c] + np.array(j)
                    c = c + 1
            except:
                print('ERROR OCCURS AT ENTRY '+str(c)+' FOR EQUITY '+symbols[c_s])
                c = c + 1
                continue
        first = False
        c_s = c_s + 1
    for k in range(0, len(avg_list)):
        avg_list[k] = avg_list[k] / len(symbols)

    return avg_list
    


def stationary_values(transition_matrix, mmult_number = 50):
    """From a transition matrix, generate stationary values"""
            
    # Create a 1st state array
    state = np.array([[0.0] * len(transition_matrix)])
    state[0][0] = 1.0

    # Create a state tracker
    stateHist = state
    dfStateHist = pd.DataFrame(state)
    distr_hist = [[0,0]]
    
    # Calculate stationary values
    for x in range(mmult_number):
        state = np.dot(state, transition_matrix)
        stateHist = np.append(stateHist,state,axis=0)
        dfDistrHist = pd.DataFrame(stateHist)
    svals = dfDistrHist[-1:].iloc[0]
        
    return svals


def plot_summaries(tms):
    """Plot it basic"""
    l_stationary = []
    for _ in tms:
        l_stationary.append(list(stationary_values([list(x) for x in _])))

        
    # Stationary Odds
    for j in range(0, 4):
        x = [x[j] for x in l_stationary]
        plt.plot(x)
    plt.legend(['Good', 'Bad', 'No Change', '3 Day Rally'])
    plt.title('Stationary Odds for Lengths of Time of Measurements')
    plt.ylabel('Chance of Occurance')
    plt.xlabel('Days')
    plt.show()
    
    
    # Transition Odds    
    for i in range(0, 2):
        for j in range(0, 2):
            x = np.array([x[i][j] for x in tms])
            plt.plot(x)
        x = np.array([x[3][i] for x in tms])
        plt.plot(x)
    plt.legend(['Good >>> Good', 'Good >>> Bad', 'Rally >>> Good', 'Bad >>> Good', 'Bad >>> Bad', 'Rally >>> Bad'])
    plt.title('Transition Odds for Lengths of Time of Measurements')
    plt.ylabel('Chance of Occurance')
    plt.xlabel('Days')
    plt.show()
    
    
    # Adjusted Stationary Odds
    for i in range(0, 2):
        for j in range(0, 2):
            x = np.array([x[i][j] for x in tms])
            x = x - [x[j] for x in l_stationary]
            plt.plot(x)
        x = np.array([x[3][i] for x in tms])
        plt.plot(x)
    plt.plot([0 for x in x]) # Plot single line
    plt.legend(['Good >>> Good', 'Good >>> Bad', 'Rally >>> Good', 'Bad >>> Good', 'Bad >>> Bad', 'Rally >>> Bad', 'Baseline'])
    plt.title('Adjusted for Stationary Odds')
    plt.ylabel('Chance of Occurance')
    plt.xlabel('Days')
    plt.show()
    
    for i in range(0, 4):
        x = np.array([1/(1-x[i][i]) if x[i][i] else None for x in tms])        
        plt.plot(x)
    plt.legend(['Good', 'Bad', 'No Change', '3 Day Rally'])
    plt.title('Mean Time in State')
    plt.ylabel('Mean Time in State')
    plt.xlabel('Days')
    plt.show()
    
    return None

# %%
tms = generate_combine_transition_matrices(symbols, start=start, end=end, min_days = 3, max_days = 10)
# Out:
# DOWNLOADING SPYG ... SUCCESS!
# DOWNLOADING SPYD ... SUCCESS!
# DOWNLOADING SPY ... SUCCESS!
# DOWNLOADING MSFT ... SUCCESS!
# DOWNLOADING AMZN ... SUCCESS!
# DOWNLOADING TSLA ... SUCCESS!
# DOWNLOADING AAPL ... SUCCESS!
# DOWNLOADING GOOGL ... SUCCESS!
# DOWNLOADING FB ... SUCCESS!
# DOWNLOADING BABA ... SUCCESS!
# DOWNLOADING TSM ... SUCCESS!
# DOWNLOADING V ... SUCCESS!
# DOWNLOADING JPM ... SUCCESS!
# DOWNLOADING JNJ ... SUCCESS!
# DOWNLOADING WMT ... SUCCESS!
# DOWNLOADING MA ... SUCCESS!
# DOWNLOADING NVDA ... SUCCESS!
# DOWNLOADING UNH ... SUCCESS!
# DOWNLOADING BAC ... SUCCESS!
# DOWNLOADING HD ... SUCCESS!
# DOWNLOADING DIS ... SUCCESS!
# DOWNLOADING PG ... SUCCESS!
# DOWNLOADING PYPL ... SUCCESS!
# DOWNLOADING CMCSA ... SUCCESS!
# DOWNLOADING XOM ... SUCCESS!
# DOWNLOADING VZ ... SUCCESS!
# DOWNLOADING KO ... SUCCESS!
# DOWNLOADING NFLX ... SUCCESS!
# DOWNLOADING T ... SUCCESS!
# DOWNLOADING ORCL ... SUCCESS!
# DOWNLOADING CSCO ... SUCCESS!
# DOWNLOADING CRM ... SUCCESS!
# DOWNLOADING PFE ... SUCCESS!
# DOWNLOADING ABT ... SUCCESS!
# DOWNLOADING TMT ... SUCCESS!
# DOWNLOADING NKE ... SUCCESS!
# DOWNLOADING CVX ... SUCCESS!
# DOWNLOADING PEP ... SUCCESS!
# DOWNLOADING ABBV ... SUCCESS!
# DOWNLOADING ACN ... SUCCESS!
# DOWNLOADING NVS ... SUCCESS!
# DOWNLOADING WFC ... SUCCESS!
# DOWNLOADING AVGO ... SUCCESS!
# DOWNLOADING MRK ... SUCCESS!
# DOWNLOADING DHR ... SUCCESS!
# DOWNLOADING TMO ... SUCCESS!
# DOWNLOADING MDT ... SUCCESS!
# DOWNLOADING UPS ... SUCCESS!
# DOWNLOADING MCD ... SUCCESS!
# DOWNLOADING LLY ... SUCCESS!
# DOWNLOADING TXN ... SUCCESS!
# DOWNLOADING SAP ... SUCCESS!
# DOWNLOADING TMUS ... SUCCESS!
# DOWNLOADING COST ... SUCCESS!
# DOWNLOADING QCOM ... SUCCESS!
# DOWNLOADING HON ... SUCCESS!
# DOWNLOADING UL ... SUCCESS!
# DOWNLOADING C ... SUCCESS!
# DOWNLOADING SHOP ... SUCCESS!
# DOWNLOADING NEE ... SUCCESS!
# DOWNLOADING LIN ... SUCCESS!
# DOWNLOADING UNP ... SUCCESS!
# <built-in method index of list object at 0x000001727039B340>
# <built-in method index of list object at 0x00000172702E0A40>
# <built-in method index of list object at 0x000001727031AFC0>
# <built-in method index of list object at 0x000001727031A900>
# <built-in method index of list object at 0x0000017270318100>
# <built-in method index of list object at 0x00000172702EC180>
# <built-in method index of list object at 0x0000017270310A40>
# <built-in method index of list object at 0x00000172702F1480>
# <built-in method index of list object at 0x000001727030EA00>
# <built-in method index of list object at 0x0000017270301B00>
# <built-in method index of list object at 0x00000172702F8B00>
# <built-in method index of list object at 0x00000172702E4E40>
# <built-in method index of list object at 0x0000017270316C00>
# <built-in method index of list object at 0x00000172702EFF00>
# <built-in method index of list object at 0x00000172702F15C0>
# <built-in method index of list object at 0x000001727030EA80>
# <built-in method index of list object at 0x0000017270315800>
# <built-in method index of list object at 0x0000017270301940>
# <built-in method index of list object at 0x00000172702C0040>
# <built-in method index of list object at 0x00000172702C43C0>
# <built-in method index of list object at 0x00000172702CC2C0>
# <built-in method index of list object at 0x00000172702D1180>
# <built-in method index of list object at 0x0000017270275740>
# <built-in method index of list object at 0x00000172702C9CC0>
# <built-in method index of list object at 0x00000172702B80C0>
# <built-in method index of list object at 0x000001727026C700>
# <built-in method index of list object at 0x000001726F95CCC0>
# <built-in method index of list object at 0x000001726E8C5940>
# <built-in method index of list object at 0x000001726F8AB300>
# <built-in method index of list object at 0x0000017270275BC0>
# <built-in method index of list object at 0x00000172702AE380>
# <built-in method index of list object at 0x000001726F8C8040>
# <built-in method index of list object at 0x000001726FA06940>
# <built-in method index of list object at 0x00000172702C6AC0>
# <built-in method index of list object at 0x000001726F9A9CC0>
# <built-in method index of list object at 0x000001727026C2C0>
# <built-in method index of list object at 0x000001726F9A9A80>
# <built-in method index of list object at 0x00000172702C6980>
# <built-in method index of list object at 0x000001726F8B6E00>
# <built-in method index of list object at 0x000001726F92A180>
# <built-in method index of list object at 0x000001726F8C27C0>
# <built-in method index of list object at 0x0000017270297380>
# <built-in method index of list object at 0x000001726F8D57C0>
# <built-in method index of list object at 0x000001726F8AE800>
# <built-in method index of list object at 0x000001726F8D53C0>
# <built-in method index of list object at 0x000001726F9FF280>
# <built-in method index of list object at 0x000001726F8C2500>
# <built-in method index of list object at 0x000001726F8C2240>
# <built-in method index of list object at 0x000001726E8C5F80>
# <built-in method index of list object at 0x000001726F8C28C0>
# <built-in method index of list object at 0x000001726F9FFB00>
# <built-in method index of list object at 0x000001726FA37700>
# <built-in method index of list object at 0x000001726F95CE00>
# <built-in method index of list object at 0x000001726F9EFD40>
# <built-in method index of list object at 0x000001726FA378C0>
# <built-in method index of list object at 0x000001727002E080>
# <built-in method index of list object at 0x000001726FA53300>
# <built-in method index of list object at 0x000001726F8B52C0>
# <built-in method index of list object at 0x00000172700494C0>
# <built-in method index of list object at 0x000001726E86BF40>
# <built-in method index of list object at 0x000001726F92ABC0>
# <built-in method index of list object at 0x000001726C4AEF00>

# %%
plt.rcParams["figure.figsize"] = (16,8)
plot_summaries(tms)
